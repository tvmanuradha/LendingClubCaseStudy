# %%
# Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading and reading dataset
df = pd.read_csv("loan.csv")
df.head()
# Out:
# C:\Users\Tuff\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# ...

# %%
# Checking shape of dataset
df.shape
# Out:
# (39717, 111)

# %%
# Checking stastical information of dataset
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
# Viewing all columns of Dataset
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
# checking is there any duplicate columns in dataset
df[df.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
# checking is there any duplicate rows in dataset 
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Dropping columns containing all null values in it
df = df.dropna(axis=1, how="all")
df.shape
# Out:
# (39717, 57)

# %%
# checking count of null values in each column
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# desc                          12940
# purpose                           0
# title                            11
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# ...

# %%
# checking percentage of null values in each column
df[df.columns[df.isnull().any()]].isnull().sum()*100/df.shape[0]
# Out:
# emp_title                      6.191303
# emp_length                     2.706650
# desc                          32.580507
# title                          0.027696
# mths_since_last_delinq        64.662487
# mths_since_last_record        92.985372
# revol_util                     0.125891
# last_pymnt_d                   0.178765
# next_pymnt_d                  97.129693
# last_credit_pull_d             0.005036
# collections_12_mths_ex_med     0.140998
# chargeoff_within_12_mths       0.140998
# pub_rec_bankruptcies           1.754916
# tax_liens                      0.098195
# dtype: float64

# %%
# Dropping columns having percentage of null values greater than 20%
df1 = ["desc","next_pymnt_d","mths_since_last_record","mths_since_last_delinq"]

# %%
df.drop(df1,axis=1,inplace=True)

# %%
# Dropping columns which is not important for analysis purpose
df2 = ["last_pymnt_d","last_credit_pull_d","collections_12_mths_ex_med","pub_rec_bankruptcies","chargeoff_within_12_mths","tax_liens"]

# %%
df.drop(df2,axis=1,inplace=True)

# %%
# checking shape of dataset after dopping null and no important columns from dataset
df.shape
# Out:
# (39717, 47)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   term                     39717 non-null  object
#  6   int_rate                 39717 non-null  object
#  7   installment              39717 non-null  float64
#  8   grade                    39717 non-null  object
#  9   sub_grade                39717 non-null  object
#  10  emp_title                37258 non-null  object
#  11  emp_length               38642 non-null  object
#  12  home_ownership           39717 non-null  object
#  13  annual_inc               39717 non-null  float64
# ...

# %%
# Replacing NaN with zero in emplyee length column as it has important information
df.emp_length.fillna(int(0), inplace=True)

# %%
# checking different values count of employee length column 
df.emp_length.value_counts()
# Out:
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# 0            1075
# Name: emp_length, dtype: int64

# %%
# Filtering  and updating employee length colum to integer as it is of Object datatype
def remove_string(x):
    x=str(x)
    s = ''.join(val for val in x if val.isdigit())
    return int(s)
df['emp_length']=df['emp_length'].apply(remove_string)
df.emp_length.dtype
# Out:
# dtype('int64')

# %%
# checking different values count of employee length column after filtering
df.emp_length.value_counts()
# Out:
# 10    8879
# 1     7823
# 2     4388
# 3     4095
# 4     3436
# 5     3282
# 6     2229
# 7     1773
# 8     1479
# 9     1258
# 0     1075
# Name: emp_length, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'purpose', 'title',
#        'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'policy_code', 'application_type', 'acc_now_delinq',
#        'delinq_amnt'],
#       dtype='object')

# %%
# checking value count of term column
df.term.value_counts()
# Out:
#  36 months    29096
#  60 months    10621
# Name: term, dtype: int64

# %%
# Filtering  and updating term column to integer as it is of Object datatype
def remove_string(x):
    x=str(x)
    s = ''.join(val for val in x if val.isdigit())
    return int(s)
df['term']=df['term'].apply(remove_string)
df.term.dtype
# Out:
# dtype('int64')

# %%
# checking value count of term column after filtering
df.term.value_counts()
# Out:
# 36    29096
# 60    10621
# Name: term, dtype: int64

# %%
# Checking value count for interest rate column
df.int_rate.value_counts()
# Out:
# 10.99%    956
# 13.49%    826
# 11.49%    825
# 7.51%     787
# 7.88%     725
#          ...
# 18.36%      1
# 16.96%      1
# 16.15%      1
# 16.01%      1
# 17.44%      1
# Name: int_rate, Length: 371, dtype: int64

# %%
# Extracting percentage sign from "int_rate" column and converting it to float value

def numeric_val(x):
    x=str(x)
    s = ''.join(val for val in x if val in "0123456789.")
    return float(s)
df['int_rate']=df['int_rate'].apply(numeric_val)

# %%
# Checking value count for interest rate column after filtering
df.int_rate.value_counts()
# Out:
# 10.99    956
# 13.49    826
# 11.49    825
# 7.51     787
# 7.88     725
#         ...
# 18.36      1
# 16.96      1
# 16.15      1
# 16.01      1
# 17.44      1
# Name: int_rate, Length: 371, dtype: int64

# %%
df.int_rate.describe()
# Out:
# count    39717.000000
# mean        12.021177
# std          3.724825
# min          5.420000
# 25%          9.250000
# 50%         11.860000
# 75%         14.590000
# max         24.590000
# Name: int_rate, dtype: float64

# %%
df.term.describe()
# Out:
# count    39717.000000
# mean        42.418007
# std         10.622815
# min         36.000000
# 25%         36.000000
# 50%         36.000000
# 75%         60.000000
# max         60.000000
# Name: term, dtype: float64

# %%
df.emp_length.describe()
# Out:
# count    39717.000000
# mean         4.954226
# std          3.461960
# min          0.000000
# 25%          2.000000
# 50%          4.000000
# 75%          9.000000
# max         10.000000
# Name: emp_length, dtype: float64

# %%
# Filing Blank value of Revolving Utility with integer 0
df.revol_util.fillna(int(0), inplace=True)

# %%
# checking value count of revol_util column
df.revol_util.value_counts()
# Out:
# 0%        977
# 0.20%      63
# 63%        62
# 0.10%      58
# 66.70%     58
#          ...
# 77.63%      1
# 25.74%      1
# 62.31%      1
# 0.83%       1
# 7.28%       1
# Name: revol_util, Length: 1090, dtype: int64

# %%
# Filtering  and updating revol_util colum to float as it is of Object datatype(by removing % sign)
def numeric_val(x):
    x=str(x)
    s = ''.join(val for val in x if val in "0123456789.")
    return float(s)
df['revol_util']=df['revol_util'].apply(numeric_val)

# %%
# checking value count of revol_util column after filtering
df.revol_util.value_counts()
# Out:
# 0.00     1027
# 0.20       63
# 63.00      62
# 40.70      58
# 66.70      58
#          ...
# 25.74       1
# 47.36       1
# 24.65       1
# 10.61       1
# 7.28        1
# Name: revol_util, Length: 1089, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 47 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   term                     39717 non-null  int64
#  6   int_rate                 39717 non-null  float64
#  7   installment              39717 non-null  float64
#  8   grade                    39717 non-null  object
#  9   sub_grade                39717 non-null  object
#  10  emp_title                37258 non-null  object
#  11  emp_length               39717 non-null  int64
#  12  home_ownership           39717 non-null  object
#  13  annual_inc               39717 non-null  float64
# ...

# %%
# Deriven metric

# %%
# Deriving new metrics "annual_inc_cat" after grouping the "annual_inc"
df["annual_inc_cat"]=pd.cut(df["annual_inc"],[0, 25000, 50000, 75000, 100000,120000],labels=["0-25000", "25000-50000", "50000-75000","75000-100000","100000+"])

# %%
# Deriving new metrics "dti_cat" after grouping the "dti"
df['dti_cat'] = pd.cut(df['dti'],[0,6,12,18,24],labels=['0-6','6-12','12-18','18+'])

# %%
# Deriving new metrics "loan_amnt_cat" after grouping the "loan_amnt rate"
df['loan_amnt_cat'] = pd.cut(df['loan_amnt'],[0,8000,16000,24000,32000],labels=['0-8000','8000-16000','16000-24000','24000+'])

# %%
# Deriving new metrics "int_rate_cat" after grouping the "interest rate"
df['int_rate_cat'] = pd.cut(df['int_rate'], [0, 5, 10, 15, 20, 25], labels=['0-5', '5-10', '10-15', '15-20','20+'])

# %%
# Deriving new metrics "loan_amnt_cat" after grouping the "loan_amnt rate"
df['loan_amnt_cat'] = pd.cut(df['loan_amnt'],[0,8000,16000,24000,32000],labels=['0-8000','8000-16000','16000-24000','24000+'])

# %%
# Deriving new metrics "revol_util_cat" after grouping the "revol_util"
df['revol_util_cat'] = pd.cut(df['revol_util'],[0.0,20.0,40.0,60.0,80.0,100.0],labels=['0.0-20.0','20.0-40.0','40.0-60.0','60.0-80.0','80.0+'])

# %%
# Changing the format of "issue_d" 
df["issue_d"]=pd.to_datetime(df.issue_d, format='%b-%y')

# %%
# Changing the format of "issue_d" into dd/mm/yyyy format
df['issue_d'] = df['issue_d'].dt.strftime('%b/%m/%y')
df['issue_d']
# Out:
# 0        Dec/12/11
# 1        Dec/12/11
# 2        Dec/12/11
# 3        Dec/12/11
# 4        Dec/12/11
#            ...
# 39712    Jul/07/07
# 39713    Jul/07/07
# 39714    Jul/07/07
# 39715    Jul/07/07
# 39716    Jun/06/07
# Name: issue_d, Length: 39717, dtype: object

# %%
# Deriving the year information and putting it into a new column called "year"
df['year']=pd.DatetimeIndex(df['issue_d']).year
df['year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 39712    2007
# 39713    2007
# 39714    2007
# 39715    2007
# 39716    2007
# Name: year, Length: 39717, dtype: int64

# %%
# Deriving the month information and putting it into a new column called "month"
df['month']=pd.DatetimeIndex(df['issue_d']).month
df['month']
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
#          ..
# 39712     7
# 39713     7
# 39714     7
# 39715     7
# 39716     6
# Name: month, Length: 39717, dtype: int64

# %%
# Conerting the information of "annual_inc" to integer data type as it contains some values in float type
df["annual_inc"]=df.annual_inc.apply(lambda x : int(x))

# %% [markdown]
# # Univariate Analysis

# %%
# Total Amount Paid boxplot
plt.figure(figsize=(13,7))
sns.boxplot(df.total_pymnt)
plt.show()
# Out:
# C:\Users\Tuff\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# dti boxplot
plt.figure(figsize=(13,7))
sns.boxplot(df.dti)
plt.show()
# Out:
# C:\Users\Tuff\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Loan Amount boxplot
plt.figure(figsize=(13,7))
sns.boxplot(df.loan_amnt)
plt.show()
# Out:
# C:\Users\Tuff\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Interest Rate boxplot
plt.figure(figsize=(13,7))
sns.boxplot(df.int_rate)
plt.show()
# Out:
# C:\Users\Tuff\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# open account Boxplot
plt.figure(figsize=(13,7))
sns.boxplot(df.open_acc)
plt.show()
# Out:
# C:\Users\Tuff\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
 # Calculating percentage of borrower belonging to different rate of interest group.
df["int_rate_cat"].value_counts().plot.pie(startangle=50, autopct='%1.1f%%')
plt.show()

# %%
# Observation : 47.3% of people got a laon on 10-15 of interest rate

# %%
# Distribution percentage of purpose of loan
sns.set(rc={'figure.figsize':(12,12)})
df.purpose.value_counts().plot(kind='pie',startangle=50, autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='purpose'>

# %%
# Observation : From the above pie_chart we observed 46.9% borrower have taken loan for "Debt_consolidation" followed by 12.9% for "credit_card"

# %%
# Percentage of current loan paying, charged off and fully paid amount people 
plt.figure(figsize=(12,12))
df["loan_status"].value_counts().plot.pie(startangle=90, autopct='%1.1f%%')
plt.show()

# %%
# Observation : Maximun borrowers paid their full loan ie:83%, while 14.2% of borrowers are charged off and 2.9% borrowers still paying their loan.

# %%
# Ploting count plot of loan status
plt.figure(figsize=(13,5),facecolor='g')
pt=sns.countplot(x="loan_status",data=df)
pt.set_title('Loan Status category - Distribution Plot',fontsize=16)
pt.set_xlabel('Loan Status category  ',fontsize=14)
plt.show()

# %%
# Observation : From the above countplot we can observe that around 32000 borrower has Fully_paid their loan while around 6000 borrower are Charged_off(debt is overdue) and around 500 borrower loan is still in processes.

# %%
# Ploting count plot of loan purpose
plt.figure(figsize=(16,8),facecolor='r')
pt=sns.countplot(x="purpose",data=df)
pt.set_title('Purpose category - Distribution Plot',fontsize=16)
pt.set_xlabel('Purpose category  ',fontsize=14)

plt.show()

# %%
# Observation : From above count plot maximum people take loan for debt_consolidation purpose followed by credit crad

# %%
# distribution plot of total payment
plt.figure(figsize=(16,8),facecolor='r')
pt=sns.distplot(df.total_pymnt,color="y")
pt.set_title('Total Payment- Distribution Plot',fontsize=16)
pt.set_xlabel('Total Payment ',fontsize=14)
plt.show()
# Out:
# C:\Users\Tuff\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Observation : Maximum borrower credit payment lies under 6000

# %%
# distribution plot of funded amount
plt.figure(figsize=(16,8),facecolor='g')
sns.set_style("darkgrid")
pt=sns.distplot(df.funded_amnt,color="r")
pt.set_title('Funded Loan Amount - Distribution Plot',fontsize=16)
pt.set_xlabel('Funded Loan Amount ',fontsize=14)
plt.show()
# Out:
# C:\Users\Tuff\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Observation : Majority of borrowers funded_amount is between 5000-10000

# %% [markdown]
# # Segmented Univariate Analysis

# %%
# Analysis of emp_length ,loan_amnt, int_rate, annual_inc, dti,revol_util to find the relation between then
employee_len_df=df.groupby(by=["emp_length"])[["loan_amnt","int_rate","annual_inc","dti","revol_util"]].mean()
employee_len_df
# Out:
#                loan_amnt   int_rate    annual_inc        dti  revol_util
# emp_length
# 0            8625.139535  10.897842  45986.771163  12.956456   42.708967
# 1            9869.417103  11.980584  61599.257190  12.769702   48.589496
# 2           10262.374658  12.074045  63274.654284  13.103719   48.636190
# 3           10738.278388  12.019673  66787.176313  13.163175   48.216542
# 4           10977.408324  12.173417  66583.750873  13.187616   49.412937
# 5           11287.035344  12.035268  68225.197441  13.421825   48.331106
# 6           11494.952894  12.070314  68184.612831  13.821350   49.591449
# 7           11739.495206  12.174969  69153.087986  13.674473   49.686317
# 8           11887.998648  11.906302  74590.461799  13.773793   48.318404
# 9           12011.625596  11.913060  74474.421304  13.540310   48.783935
# 10          13089.970717  12.094797  81706.525735  13.716438   49.584756

# %%
# Observation : With the increase of the working experience the annual income of the borrower increases along with loan amount

# %%
# Analysis of month ,year, loan_amnt, int_rate to find the relation between then
month_year_df=df.groupby(by=['month','year'])[['loan_amnt','int_rate']].mean()
month_year_df
# Out:
#                loan_amnt   int_rate
# month year
# 1     2008  10298.538012  10.545380
#       2009   9147.384937  12.149372
#       2010  11171.010187  12.174312
#       2011  10742.445652  11.106797
# 2     2008   9651.580460  10.742471
#       2009   9004.134615  12.633654
#       2010  10820.933014  11.548453
#       2011  11245.393215  11.690786
# 3     2008  11414.936441  11.143686
#       2009   9613.224638  12.503986
#       2010  10364.077341  11.570882
#       2011  11436.781012  11.951317
# 4     2008  10040.645161  11.078258
#       2009   9235.000000  12.270862
#       2010  10468.047158  11.601911
#       2011  11217.717670  11.717542
# 5     2008   5900.000000  10.470563
#       2009   9765.360502  11.993229
#       2010  10796.413043  11.805913
#       2011  11286.101243  12.623529
# 6     2007   7500.000000  13.750000
#       2008   5757.196970  10.613939
#       2009   8967.275281  11.786011
#       2010  10179.203110  12.391195
# ...

# %%
# Observation : From year 2007 to 2011 throughout the month the loan amount is maximum in year 2011

# %% [markdown]
# # Bivariate Analysis

# %%
# Creating a boxplot of "int_rate_cat"  and "funded_amnt"
plt.figure(figsize=(16,8),facecolor='r')
pt=sns.boxplot(y='int_rate_cat',x="funded_amnt",data=df)
pt.set_title('Rate of Interest Vs Funded Loan Amount',fontsize=14)
pt.set_ylabel('Loan Rate of Interest',fontsize=14)
pt.set_xlabel('Funded Loan Amount',fontsize=14)      
plt.show()

# %%
# Observation : The median value of loan amount increase as rate of interest increases

# %%
# Creating a boxplot of "int_rate"  and "term"
plt.figure(figsize=(16,8),facecolor='g')
pt=sns.boxplot(y='int_rate',x="term",data=df)
pt.set_title('Interest_rate vs Term',fontsize=14)
pt.set_ylabel('Loan Rate of Interest',fontsize=14)
pt.set_xlabel('Loan Term in Month',fontsize=14)      
plt.show()

# %%
# Observation : From the box plot we observe that borrower taken loan for longer duartion i.e:60_months have assign high interest_rate as compare to 36_months.

# %%
# Creating a countplot of "purpose" of loan  and "loan_status"
plt.figure(figsize=(16,8),facecolor='g')
pt=sns.countplot(y="purpose",data=df,hue='loan_status')
pt.set_title('Purpose Of Loans Vs loan_status',fontsize=14)
pt.set_ylabel('Purpose Of Loan',fontsize=14)
pt.set_xlabel('Count of Loan Application ',fontsize=14)      
plt.show()

# %%
# Observation : As most borrower have taken loan for debt_consolidation there is a high number of Fully_Paid status in debt_consolidation and Charged_Off.

# %%
# Creating a countplot of "loan_status" and "int_rate_cat"
plt.figure(figsize=(16,8),facecolor='r')
pt=sns.countplot(y="loan_status",data=df,hue='int_rate_cat')
pt.set_title('Interest_rate_category Vs Loan Status',fontsize=14)
pt.set_ylabel('Loan Status ',fontsize=14)
pt.set_xlabel('Count',fontsize=14)      
plt.show()

# %%
# Observation :

#1) Interest_rate between 10-15 and 5-10 have high number of ratio of paying their loan.

#2) Interest_rate betweem 10-15 and 15-20 have high number of ratio of Charged_Off.

# %%
# Creating a countplot of "emp_length" and "loan_status"
plt.figure(figsize=(15,5),facecolor='g')
pt=sns.countplot(y="emp_length",data=df,hue='loan_status')
pt.set_title('Time of Job Vs Credit Status',fontsize=14)
pt.set_ylabel('Employee_length',fontsize=14)
pt.set_xlabel('Count of Loan Application ',fontsize=14)      
plt.show()

# %%
# Observation : People having employee length of 1 and 10 have mostly paid their loan

# %%
# Creating a countplot of "emp_length" and "purpose" of loan
plt.figure(figsize=(15,10),facecolor='r')
sns.set_style('white')
pt=sns.countplot(y="emp_length",data=df,hue='purpose')
pt.set_title('Time of Job Vs Credit Status',fontsize=14)
pt.set_ylabel('Employee_length',fontsize=14)
pt.set_xlabel('Count of Loan Application ',fontsize=14)      
plt.show()

# %%
# Observation : 

#1) borrower at starting of their job around 1 year people takes more loan which decreases from 2,3,4,5 consecutively.

#2) Majority of borrower with less than 3 years of experience has paid their loans amount before given time (as loan term is of 36 and 60 months).

#3) borrower with working experience of 10+ year takes maximum loans as their responsibilty increased.

# %%
# Creating a countplot of "home_ownership" and "loan_status" 
plt.figure(figsize=(16,8),facecolor='g')
pt=sns.countplot(y="home_ownership",data=df,hue='loan_status')
pt.set_title('Home Status Vs Purpose Of Loans',fontsize=14)
pt.set_ylabel('Home Ownership',fontsize=14)
pt.set_xlabel('Loan Status ',fontsize=14)      
plt.show()

# %%
# Observation :

#1) The highest proportion of the borrowers use to live in rented housing followed by mortgage house

#2) Maximum charged of borrowers lives in a rented house

#3) Borrowers with own house takes less number of loans in comparision to rented and mortgage borrowers

# %%
# Creating a countplot of "dti_cat" and "loan_status" 
plt.figure(figsize=(16,8),facecolor='r')
pt=sns.countplot(y="loan_status",data=df,hue='dti_cat')
pt.set_title('DTI Vs Loan_status',fontsize=14)
pt.set_ylabel('Loan Status ',fontsize=14)
pt.set_xlabel('DTI',fontsize=14)      
plt.show()

# %%
# Observation :

#1) From above countplot we observe dti ratio between 12-18 have maximum paid their full loan followed by 6-12 dti.

#2) while dti ratio of 12-18 also have maximum number of Charged_Off followed by dti ratio of 18+

# %%
# Creating a countplot of "loan_status"  and "grade" of borrower 
plt.figure(figsize=(16,8),facecolor='r')
pt=sns.countplot(y="loan_status",data=df,hue='grade')
pt.set_title('Grade Vs Loan Status',fontsize=14)
pt.set_ylabel('Loan Status ',fontsize=14)
pt.set_xlabel('Grade Count',fontsize=14)      
plt.show()

# %%
# Observation :

#1)Grade A and B have high number of ratio of paying their full loan.

#2)Grade B and C have high number of ratio of not paying their in time in case of Charged_Off.

#3)Borrowers with B grade is maximum in the category of fully_paid,charged_off and current.

# %%
# Creating a countplot of "int_rate_cat"  and "grade" of borrower 
plt.figure(figsize=(16,8),facecolor='g')
pt=sns.countplot(y="int_rate_cat",data=df,hue='grade')
pt.set_title('Interest_rate vs Grade',fontsize=14)
pt.set_ylabel('interset_rate_Category ',fontsize=14)
pt.set_xlabel('Customer Credit Grade',fontsize=14)      
plt.show()

# %%
# Observation :

#1) Borrowers with A grade likely to get loans at a lower interest rate of 5%-10%.

#2)Borrowers with lower grade(G,E,F) likely to get loans at a higher interest rate of 20% and above

# %% [markdown]
# # Multivariate Analysis

# %%
# Creating a barplot of "year" , "loan_amnt" and "loan_status"
plt.figure(figsize=(10,10))
sns.barplot(x='year', y='loan_amnt', data =df,hue ='loan_status')
plt.show()

# %%
# Observation :

#1) The fully_paid borrowers increases continously increase from year 2007 to 2011.

#2) It has been observed every yeat between 2007 to 2011 the number of charged off borrower is more than the number of fully paid borrowers

# %%
# Creating a barplot of "loan_amnt" , "purpose" and "loan_status" 
plt.figure(figsize=(10,10))
sns.barplot(x='loan_amnt', y='purpose',data =df, hue ='loan_status')
plt.show()

# %%
# Observation : Among all the purpose of loan the majority of the loan are there in current state, with higher loan amount in comparison to other purposes

# %%
# Creating a barplot of "loan_amnt_cat" , "open_acc" and "revol_util_cat" t
plt.figure(figsize=(10,10))
sns.barplot(x='loan_amnt_cat', y='open_acc', data =df,hue ='revol_util_cat')
plt.show()

# %%
# Observation : Throughout all the loans borrowers uses revolving amount with maximum utilization percentage band of 20% to 40% while borrowers uses revolving amount with minimum utilization percentage band of 80+

# %%
# Creating a barplot of "loan_amnt" , "emp_length" and "loan_status"
plt.figure(figsize=(15,10))
sns.barplot(data =df,y='loan_amnt', x='emp_length', hue ='loan_status',palette="pastel")
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='loan_amnt'>

# %%
# Creating a barplot of "loan_amnt" , "verification_status" and "loan_status"
plt.figure(figsize=(15,10))
sns.barplot(data =df,y='loan_amnt', x='verification_status', hue ='loan_status',palette="pastel")
# Out:
# <AxesSubplot:xlabel='verification_status', ylabel='loan_amnt'>

# %%
# Observation : 

#1) Employees with longer working experience has got the loan approved for a higher amount.

#2) Borrower whose source of income is verified by LC gets loan of higher amount

# %%
# Creating a barplot of "annual_inc" , "purpose" and "loan_status"
plt.figure(figsize=(10,10))
sns.barplot(data =df,x='annual_inc', y='purpose', hue ='loan_status',palette="deep")
plt.show()

# %%
# Observation : Borrower with higher salary mostly applied loans for "home_improvment", "house", "renewable_energy" and "small_businesses"
